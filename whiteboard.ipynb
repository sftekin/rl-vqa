# %%
import json


data_file = "data/ocr/dataset.json"

with open(data_file, "r") as f:
    data = json.load(f)

# %%
data
# Out:
# {'761183272': {'imageURL': 'http://ecx.images-amazon.com/images/I/61Y5cOdHJbL.jpg',
#   'questions': ['Who wrote this book?',
#    'What is the title of this book?',
#    'What is the genre of this book?',
#    'Is this a games related book?',
#    'What is the year printed on this calendar?'],
#   'answers': ['Sandra Boynton',
#    "Mom's Family Wall Calendar 2016",
#    'Calendars',
#    'No',
#    '2016'],
#   'title': "Mom's Family Wall Calendar 2016",
#   'authorName': 'Sandra Boynton',
#   'genre': 'Calendars',
#   'split': 1},
#  '1623439671': {'imageURL': 'http://ecx.images-amazon.com/images/I/61t-hrSw9BL.jpg',
#   'questions': ['Who wrote this book?',
#    'What is the title of this book?',
#    'What is the genre of this book?',
#    'Is this a historical book?',
#    'What is the year printed on this calendar?'],
#   'answers': ['Doug the Pug',
#    'Doug the Pug 2016 Wall Calendar',
#    'Calendars',
#    'No',
#    '2016'],
# ...
